# %%
import re
import requests
import json
from bs4 import BeautifulSoup
from tqdm import tqdm

# %%
def build_request_url(ticker: str, region_code='usa'):
    request_api_prefix = 'http://financials.morningstar.com/ajax/ReportProcess4HtmlAjax.html?'	
    ticker_param = f't={ticker}&region={region_code}&culture=en-US&reportType=cf&period=12&dataType=A&order=asc&columnYear=5&curYearPart=1st5year&rounding=3&number=1'
    return request_api_prefix + ticker_param

# %%
URL = build_request_url('AMZN')
URL
# Out:
# 'http://financials.morningstar.com/ajax/ReportProcess4HtmlAjax.html?t=AMZN&region=usa&culture=en-US&reportType=cf&period=12&dataType=A&order=asc&columnYear=5&curYearPart=1st5year&rounding=3&number=1'

# %%
text = requests.get(URL).text
text = re.sub('\'', '', text)

js = json.loads(text)
html = js['result']
soup = BeautifulSoup(html, 'html.parser')

# %%
tags = soup.find_all('div')
info = {}

for tag in tqdm(tags):
        debug_tag = tag
        attrs = tag.attrs

        if 'id' in attrs:
            tag_id = tag['id']
            value = tag.text

            # Parse currency and FY End month number
            if tag_id == 'unitsAndFiscalYear':
                info['fye_month'] = int(tag['fyenumber'])
                info['currency'] = tag['currency']

            # Parse Yrly or Qtrly values
            elif tag_id[:2] == 'Y_':
                parent_id = tag.parent['id']
                key = f'{parent_id}_{tag_id}'

                if 'rawvalue' in attrs:
                    # parse values i.e data_{statid}_{yearid} -> float value
                    if tag['rawvalue'] in ['—', 'nbsp']:
                        continue
                    info[key] = float(re.sub(',', '', tag['rawvalue']))
                    print('2.1', key)
                else:
                    # parse year labels i.e. Y_1 -> 2017-12
                    if 'title' in attrs:
                        value = tag['title']
                    info[key] = value
                    print('2.2', key, value)

            # Parse labels i.e. label_i4 -> Inventories
            elif tag_id[:3] == 'lab' and 'padding' not in tag_id:
                lbl_tag = tag.find("div", class_="lbl")
                value = lbl_tag['title'] if 'title' in lbl_tag.attrs else lbl_tag.text
                info[tag_id] = value
                print('3', tag_id, value)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 648/648 [00:00<00:00, 34711.92it/s]
# 3 label_s1 Cash Flows From Operating Activities
# 3 label_i1 Net income
# 3 label_i2 Depreciation & amortization
# 3 label_i3 Amortization of debt discount/premium and issuance costs
# 3 label_i4 Investment/asset impairment charges
# 3 label_i5 Investments losses (gains)
# 3 label_i6 Deferred income taxes
# 3 label_i7 (Gain) Loss from discontinued operations
# 3 label_i8 Extraordinary items
# 3 label_i9 Cumulative effect of accounting change
# 3 label_i10 Stock based compensation
# 3 label_i15 Change in working capital
# 3 label_i16 Accounts receivable
# 3 label_i17 Inventory
# 3 label_i18 Prepaid expenses
# 3 label_i19 Accounts payable
# 3 label_i20 Accrued liabilities
# 3 label_i21 Interest payable
# 3 label_i22 Income taxes payable
# 3 label_i23 Other working capital
# 3 label_i30 Other non-cash items
# 3 label_tts1 Net cash provided by operating activities
# 3 label_s2 Cash Flows From Investing Activities
# 3 label_i31 Investments in property, plant, and equipment
# 3 label_i32 Property, plant, and equipment reductions
# 3 label_i33 Acquisitions, net
# 3 label_i34 Purchases of investments
# 3 label_i35 Sales/Maturities of investments
# 3 label_i36 Investments in technologies
# 3 label_i37 Sales of technologies
# 3 label_i38 Purchases of intangibles
# 3 label_i39 Sales of intangibles
# 3 label_i60 Other investing activities
# 3 label_tts2 Net cash used for investing activities
# 3 label_s3 Cash Flows From Financing Activities
# 3 label_i61 Debt issued
# 3 label_i62 Debt repayment
# 3 label_i63 Preferred stock issued
# 3 label_i64 Preferred stock repaid
# 3 label_i65 Warrant issued
# 3 label_i66 Common stock issued
# 3 label_i67 Common stock repurchased
# 3 label_i68 Excess tax benefit from stock based compensation
# 3 label_i69 Dividend paid
# 3 label_i70 Dividend payable
# 3 label_i90 Other financing activities
# 3 label_tts3 Net cash provided by (used for) financing activities
# 3 label_i91 Effect of exchange rate changes
# 3 label_i93 Net change in cash
# 3 label_i94 Cash at beginning of period
# 3 label_i95 Cash at end of period
# 3 label_g7 Free Cash Flow
# 3 label_i100 Operating cash flow
# 3 label_i96 Capital expenditure
# 3 label_i97 Free cash flow
# 2.2 Year_Y_1 2017-12
# 2.2 Year_Y_2 2018-12
# 2.2 Year_Y_3 2019-12
# 2.2 Year_Y_4 2020-12
# 2.2 Year_Y_5 2021-12
# 2.2 Year_Y_6 TTM
# 2.1 data_s1_Y_1
# 2.1 data_s1_Y_2
# 2.1 data_s1_Y_3
# 2.1 data_s1_Y_4
# 2.1 data_s1_Y_5
# 2.1 data_s1_Y_6
# 2.1 data_i1_Y_1
# 2.1 data_i1_Y_2
# 2.1 data_i1_Y_3
# 2.1 data_i1_Y_4
# 2.1 data_i1_Y_5
# 2.1 data_i1_Y_6
# 2.1 data_i2_Y_1
# 2.1 data_i2_Y_2
# 2.1 data_i2_Y_3
# 2.1 data_i2_Y_4
# 2.1 data_i2_Y_5
# 2.1 data_i2_Y_6
# 2.1 data_i6_Y_1
# 2.1 data_i6_Y_2
# 2.1 data_i6_Y_3
# 2.1 data_i6_Y_4
# 2.1 data_i6_Y_5
# 2.1 data_i6_Y_6
# 2.1 data_i10_Y_1
# 2.1 data_i10_Y_2
# 2.1 data_i10_Y_3
# 2.1 data_i10_Y_4
# 2.1 data_i10_Y_5
# 2.1 data_i10_Y_6
# 2.1 data_i15_Y_1
# 2.1 data_i15_Y_2
# 2.1 data_i15_Y_3
# 2.1 data_i15_Y_4
# 2.1 data_i15_Y_5
# 2.1 data_i15_Y_6
# 2.1 data_i16_Y_1
# 2.1 data_i16_Y_2
# 2.1 data_i16_Y_3
# 2.1 data_i16_Y_4
# 2.1 data_i16_Y_5
# 2.1 data_i16_Y_6
# 2.1 data_i17_Y_1
# 2.1 data_i17_Y_2
# 2.1 data_i17_Y_3
# 2.1 data_i17_Y_4
# 2.1 data_i17_Y_5
# 2.1 data_i17_Y_6
# 2.1 data_i19_Y_1
# 2.1 data_i19_Y_2
# 2.1 data_i19_Y_3
# 2.1 data_i19_Y_4
# 2.1 data_i19_Y_5
# 2.1 data_i19_Y_6
# 2.1 data_i20_Y_1
# 2.1 data_i20_Y_2
# 2.1 data_i20_Y_3
# 2.1 data_i20_Y_4
# 2.1 data_i20_Y_5
# 2.1 data_i20_Y_6
# 2.1 data_i23_Y_1
# 2.1 data_i23_Y_2
# 2.1 data_i23_Y_3
# 2.1 data_i23_Y_4
# 2.1 data_i23_Y_5
# 2.1 data_i23_Y_6
# 2.1 data_i30_Y_1
# 2.1 data_i30_Y_2
# 2.1 data_i30_Y_3
# 2.1 data_i30_Y_4
# 2.1 data_i30_Y_5
# 2.1 data_i30_Y_6
# 2.1 data_tts1_Y_1
# 2.1 data_tts1_Y_2
# 2.1 data_tts1_Y_3
# 2.1 data_tts1_Y_4
# 2.1 data_tts1_Y_5
# 2.1 data_tts1_Y_6
# 2.1 data_s2_Y_1
# 2.1 data_s2_Y_2
# 2.1 data_s2_Y_3
# 2.1 data_s2_Y_4
# 2.1 data_s2_Y_5
# 2.1 data_s2_Y_6
# 2.1 data_i31_Y_1
# 2.1 data_i31_Y_2
# 2.1 data_i31_Y_3
# 2.1 data_i31_Y_4
# 2.1 data_i31_Y_5
# 2.1 data_i31_Y_6
# 2.1 data_i32_Y_1
# 2.1 data_i32_Y_2
# 2.1 data_i32_Y_3
# 2.1 data_i32_Y_4
# 2.1 data_i32_Y_5
# 2.1 data_i32_Y_6
# 2.1 data_i33_Y_1
# 2.1 data_i33_Y_2
# 2.1 data_i33_Y_3
# 2.1 data_i33_Y_4
# 2.1 data_i33_Y_5
# 2.1 data_i33_Y_6
# 2.1 data_i34_Y_1
# 2.1 data_i34_Y_2
# 2.1 data_i34_Y_3
# 2.1 data_i34_Y_4
# 2.1 data_i34_Y_5
# 2.1 data_i34_Y_6
# 2.1 data_i35_Y_1
# 2.1 data_i35_Y_2
# 2.1 data_i35_Y_3
# 2.1 data_i35_Y_4
# 2.1 data_i35_Y_5
# 2.1 data_i35_Y_6
# 2.1 data_tts2_Y_1
# 2.1 data_tts2_Y_2
# 2.1 data_tts2_Y_3
# 2.1 data_tts2_Y_4
# 2.1 data_tts2_Y_5
# 2.1 data_tts2_Y_6
# 2.1 data_s3_Y_1
# 2.1 data_s3_Y_2
# 2.1 data_s3_Y_3
# 2.1 data_s3_Y_4
# 2.1 data_s3_Y_5
# 2.1 data_s3_Y_6
# 2.1 data_i61_Y_1
# 2.1 data_i61_Y_2
# 2.1 data_i61_Y_3
# 2.1 data_i61_Y_4
# 2.1 data_i61_Y_5
# 2.1 data_i61_Y_6
# 2.1 data_i62_Y_1
# 2.1 data_i62_Y_2
# 2.1 data_i62_Y_3
# 2.1 data_i62_Y_4
# 2.1 data_i62_Y_5
# 2.1 data_i62_Y_6
# 2.1 data_tts3_Y_1
# 2.1 data_tts3_Y_2
# 2.1 data_tts3_Y_3
# 2.1 data_tts3_Y_4
# 2.1 data_tts3_Y_5
# 2.1 data_tts3_Y_6
# 2.1 data_i91_Y_1
# 2.1 data_i91_Y_2
# 2.1 data_i91_Y_3
# 2.1 data_i91_Y_4
# 2.1 data_i91_Y_5
# 2.1 data_i91_Y_6
# 2.1 data_i93_Y_1
# 2.1 data_i93_Y_2
# 2.1 data_i93_Y_3
# 2.1 data_i93_Y_4
# 2.1 data_i93_Y_5
# 2.1 data_i93_Y_6
# 2.1 data_i94_Y_1
# 2.1 data_i94_Y_2
# 2.1 data_i94_Y_3
# 2.1 data_i94_Y_4
# 2.1 data_i94_Y_5
# 2.1 data_i94_Y_6
# 2.1 data_i95_Y_1
# 2.1 data_i95_Y_2
# 2.1 data_i95_Y_3
# 2.1 data_i95_Y_4
# 2.1 data_i95_Y_5
# 2.1 data_i95_Y_6
# 2.1 data_i100_Y_1
# 2.1 data_i100_Y_2
# 2.1 data_i100_Y_3
# 2.1 data_i100_Y_4
# 2.1 data_i100_Y_5
# 2.1 data_i100_Y_6
# 2.1 data_i96_Y_1
# 2.1 data_i96_Y_2
# 2.1 data_i96_Y_3
# 2.1 data_i96_Y_4
# 2.1 data_i96_Y_5
# 2.1 data_i96_Y_6
# 2.1 data_i97_Y_1
# 2.1 data_i97_Y_2
# 2.1 data_i97_Y_3
# 2.1 data_i97_Y_4
# 2.1 data_i97_Y_5
# 2.1 data_i97_Y_6

# %%
info['fye_month'], info['currency']
# Out:
# (12, 'USD')

# %% [markdown]
# label_{sid}, Year_{pid}, data_{sid}_{pid}

# %% [markdown]
# stmt = {'fye_month':info['fye_month'],
#         'currency': info['currency'],
#         'balance_sheet':bs_data,
#         'income_statement': is_data,
#         'cashflow_statement': cf_data}

# %%
label_pattern = re.compile(r'label_(.*)')
year_pattern = re.compile(r'Year_(.*)')
stats = [k for k in info if label_pattern.search(k)]
years = [k for k in info if year_pattern.search(k)]

# %%
stmt_data = []
for stat in stats:
    sid = label_pattern.search(stat).group(1)
    stat_values = []
    for year in years:
        yid = year_pattern.search(year).group(1)
        key = f'data_{sid}_{yid}'
        stat_values.append({'period': info[year], 'value': info.get(key, float('nan'))})
    stmt_data.append({'name': info[stat], 'values': stat_values})

# %%
stmt_data
# Out:
# [{'name': 'Cash Flows From Operating Activities',
#   'values': [{'period': '2017-12', 'value': 18434000000.0},
#    {'period': '2018-12', 'value': 30723000000.0},
#    {'period': '2019-12', 'value': 38514000000.0},
#    {'period': '2020-12', 'value': 66064000000.0},
#    {'period': '2021-12', 'value': 46327000000.0},
#    {'period': 'TTM', 'value': 46327000000.0}]},
#  {'name': 'Net income',
#   'values': [{'period': '2017-12', 'value': 3033000000.0},
#    {'period': '2018-12', 'value': 10073000000.0},
#    {'period': '2019-12', 'value': 11588000000.0},
#    {'period': '2020-12', 'value': 21331000000.0},
#    {'period': '2021-12', 'value': 33364000000.0},
#    {'period': 'TTM', 'value': 33364000000.0}]},
#  {'name': 'Depreciation & amortization',
#   'values': [{'period': '2017-12', 'value': 11478000000.0},
#    {'period': '2018-12', 'value': 15341000000.0},
#    {'period': '2019-12', 'value': 21789000000.0},
#    {'period': '2020-12', 'value': 25251000000.0},
#    {'period': '2021-12', 'value': 34296000000.0},
#    {'period': 'TTM', 'value': 34296000000.0}]},
#  {'name': 'Amortization of debt discount/premium and issuance costs',
#   'values': [{'period': '2017-12', 'value': nan},
#    {'period': '2018-12', 'value': nan},
#    {'period': '2019-12', 'value': nan},
#    {'period': '2020-12', 'value': nan},
#    {'period': '2021-12', 'value': nan},
#    {'period': 'TTM', 'value': nan}]},
#  {'name': 'Investment/asset impairment charges',
#   'values': [{'period': '2017-12', 'value': nan},
#    {'period': '2018-12', 'value': nan},
#    {'period': '2019-12', 'value': nan},
#    {'period': '2020-12', 'value': nan},
#    {'period': '2021-12', 'value': nan},
#    {'period': 'TTM', 'value': nan}]},
#  {'name': 'Investments losses (gains)',
#   'values': [{'period': '2017-12', 'value': nan},
#    {'period': '2018-12', 'value': nan},
#    {'period': '2019-12', 'value': nan},
#    {'period': '2020-12', 'value': nan},
#    {'period': '2021-12', 'value': nan},
#    {'period': 'TTM', 'value': nan}]},
#  {'name': 'Deferred income taxes',
#   'values': [{'period': '2017-12', 'value': -29000000.0},
#    {'period': '2018-12', 'value': 441000000.0},
#    {'period': '2019-12', 'value': 796000000.0},
#    {'period': '2020-12', 'value': -554000000.0},
#    {'period': '2021-12', 'value': -310000000.0},
#    {'period': 'TTM', 'value': -310000000.0}]},
#  {'name': '(Gain) Loss from discontinued operations',
#   'values': [{'period': '2017-12', 'value': nan},
#    {'period': '2018-12', 'value': nan},
#    {'period': '2019-12', 'value': nan},
#    {'period': '2020-12', 'value': nan},
#    {'period': '2021-12', 'value': nan},
#    {'period': 'TTM', 'value': nan}]},
#  {'name': 'Extraordinary items',
#   'values': [{'period': '2017-12', 'value': nan},
#    {'period': '2018-12', 'value': nan},
#    {'period': '2019-12', 'value': nan},
#    {'period': '2020-12', 'value': nan},
#    {'period': '2021-12', 'value': nan},
#    {'period': 'TTM', 'value': nan}]},
#  {'name': 'Cumulative effect of accounting change',
#   'values': [{'period': '2017-12', 'value': nan},
#    {'period': '2018-12', 'value': nan},
#    {'period': '2019-12', 'value': nan},
#    {'period': '2020-12', 'value': nan},
#    {'period': '2021-12', 'value': nan},
#    {'period': 'TTM', 'value': nan}]},
#  {'name': 'Stock based compensation',
#   'values': [{'period': '2017-12', 'value': 4215000000.0},
#    {'period': '2018-12', 'value': 5418000000.0},
#    {'period': '2019-12', 'value': 6864000000.0},
#    {'period': '2020-12', 'value': 9208000000.0},
#    {'period': '2021-12', 'value': 12757000000.0},
#    {'period': 'TTM', 'value': 12757000000.0}]},
#  {'name': 'Change in working capital',
#   'values': [{'period': '2017-12', 'value': -173000000.0},
#    {'period': '2018-12', 'value': -1043000000.0},
#    {'period': '2019-12', 'value': -2438000000.0},
#    {'period': '2020-12', 'value': 13481000000.0},
#    {'period': '2021-12', 'value': -19611000000.0},
#    {'period': 'TTM', 'value': -19611000000.0}]},
#  {'name': 'Accounts receivable',
#   'values': [{'period': '2017-12', 'value': -4786000000.0},
#    {'period': '2018-12', 'value': -4615000000.0},
#    {'period': '2019-12', 'value': -7681000000.0},
#    {'period': '2020-12', 'value': -8169000000.0},
#    {'period': '2021-12', 'value': -18163000000.0},
#    {'period': 'TTM', 'value': -18163000000.0}]},
#  {'name': 'Inventory',
#   'values': [{'period': '2017-12', 'value': -3583000000.0},
#    {'period': '2018-12', 'value': -1314000000.0},
#    {'period': '2019-12', 'value': -3278000000.0},
#    {'period': '2020-12', 'value': -2849000000.0},
#    {'period': '2021-12', 'value': -9487000000.0},
#    {'period': 'TTM', 'value': -9487000000.0}]},
#  {'name': 'Prepaid expenses',
#   'values': [{'period': '2017-12', 'value': nan},
#    {'period': '2018-12', 'value': nan},
#    {'period': '2019-12', 'value': nan},
#    {'period': '2020-12', 'value': nan},
#    {'period': '2021-12', 'value': nan},
#    {'period': 'TTM', 'value': nan}]},
#  {'name': 'Accounts payable',
#   'values': [{'period': '2017-12', 'value': 7175000000.0},
#    {'period': '2018-12', 'value': 3263000000.0},
#    {'period': '2019-12', 'value': 8193000000.0},
#    {'period': '2020-12', 'value': 17480000000.0},
#    {'period': '2021-12', 'value': 3602000000.0},
#    {'period': 'TTM', 'value': 3602000000.0}]},
#  {'name': 'Accrued liabilities',
#   'values': [{'period': '2017-12', 'value': 283000000.0},
#    {'period': '2018-12', 'value': 472000000.0},
#    {'period': '2019-12', 'value': -1383000000.0},
#    {'period': '2020-12', 'value': 5754000000.0},
#    {'period': '2021-12', 'value': 2123000000.0},
#    {'period': 'TTM', 'value': 2123000000.0}]},
#  {'name': 'Interest payable',
#   'values': [{'period': '2017-12', 'value': nan},
#    {'period': '2018-12', 'value': nan},
#    {'period': '2019-12', 'value': nan},
#    {'period': '2020-12', 'value': nan},
#    {'period': '2021-12', 'value': nan},
#    {'period': 'TTM', 'value': nan}]},
#  {'name': 'Income taxes payable',
#   'values': [{'period': '2017-12', 'value': nan},
#    {'period': '2018-12', 'value': nan},
#    {'period': '2019-12', 'value': nan},
#    {'period': '2020-12', 'value': nan},
#    {'period': '2021-12', 'value': nan},
#    {'period': 'TTM', 'value': nan}]},
#  {'name': 'Other working capital',
#   'values': [{'period': '2017-12', 'value': 738000000.0},
#    {'period': '2018-12', 'value': 1151000000.0},
#    {'period': '2019-12', 'value': 1711000000.0},
#    {'period': '2020-12', 'value': 1265000000.0},
#    {'period': '2021-12', 'value': 2314000000.0},
#    {'period': 'TTM', 'value': 2314000000.0}]},
#  {'name': 'Other non-cash items',
#   'values': [{'period': '2017-12', 'value': -90000000.0},
#    {'period': '2018-12', 'value': 493000000.0},
#    {'period': '2019-12', 'value': -85000000.0},
#    {'period': '2020-12', 'value': -2653000000.0},
#    {'period': '2021-12', 'value': -14169000000.0},
#    {'period': 'TTM', 'value': -14169000000.0}]},
#  {'name': 'Net cash provided by operating activities',
#   'values': [{'period': '2017-12', 'value': 18434000000.0},
#    {'period': '2018-12', 'value': 30723000000.0},
#    {'period': '2019-12', 'value': 38514000000.0},
#    {'period': '2020-12', 'value': 66064000000.0},
#    {'period': '2021-12', 'value': 46327000000.0},
#    {'period': 'TTM', 'value': 46327000000.0}]},
#  {'name': 'Cash Flows From Investing Activities',
#   'values': [{'period': '2017-12', 'value': -27819000000.0},
#    {'period': '2018-12', 'value': -12369000000.0},
#    {'period': '2019-12', 'value': -24281000000.0},
#    {'period': '2020-12', 'value': -59611000000.0},
#    {'period': '2021-12', 'value': -58154000000.0},
#    {'period': 'TTM', 'value': -58154000000.0}]},
#  {'name': 'Investments in property, plant, and equipment',
#   'values': [{'period': '2017-12', 'value': -11955000000.0},
#    {'period': '2018-12', 'value': -13427000000.0},
#    {'period': '2019-12', 'value': -16861000000.0},
#    {'period': '2020-12', 'value': -40140000000.0},
#    {'period': '2021-12', 'value': -61053000000.0},
#    {'period': 'TTM', 'value': -61053000000.0}]},
#  {'name': 'Property, plant, and equipment reductions',
#   'values': [{'period': '2017-12', 'value': 1897000000.0},
#    {'period': '2018-12', 'value': 2104000000.0},
#    {'period': '2019-12', 'value': 4172000000.0},
#    {'period': '2020-12', 'value': 5096000000.0},
#    {'period': '2021-12', 'value': 5657000000.0},
#    {'period': 'TTM', 'value': 5657000000.0}]},
#  {'name': 'Acquisitions, net',
#   'values': [{'period': '2017-12', 'value': -13972000000.0},
#    {'period': '2018-12', 'value': -2186000000.0},
#    {'period': '2019-12', 'value': -2461000000.0},
#    {'period': '2020-12', 'value': -2325000000.0},
#    {'period': '2021-12', 'value': -1985000000.0},
#    {'period': 'TTM', 'value': -1985000000.0}]},
#  {'name': 'Purchases of investments',
#   'values': [{'period': '2017-12', 'value': -13777000000.0},
#    {'period': '2018-12', 'value': -7100000000.0},
#    {'period': '2019-12', 'value': -31812000000.0},
#    {'period': '2020-12', 'value': -72479000000.0},
#    {'period': '2021-12', 'value': -60157000000.0},
#    {'period': 'TTM', 'value': -60157000000.0}]},
#  {'name': 'Sales/Maturities of investments',
#   'values': [{'period': '2017-12', 'value': 9988000000.0},
#    {'period': '2018-12', 'value': 8240000000.0},
#    {'period': '2019-12', 'value': 22681000000.0},
#    {'period': '2020-12', 'value': 50237000000.0},
#    {'period': '2021-12', 'value': 59384000000.0},
#    {'period': 'TTM', 'value': 59384000000.0}]},
#  {'name': 'Investments in technologies',
#   'values': [{'period': '2017-12', 'value': nan},
#    {'period': '2018-12', 'value': nan},
#    {'period': '2019-12', 'value': nan},
#    {'period': '2020-12', 'value': nan},
#    {'period': '2021-12', 'value': nan},
#    {'period': 'TTM', 'value': nan}]},
#  {'name': 'Sales of technologies',
#   'values': [{'period': '2017-12', 'value': nan},
#    {'period': '2018-12', 'value': nan},
#    {'period': '2019-12', 'value': nan},
#    {'period': '2020-12', 'value': nan},
#    {'period': '2021-12', 'value': nan},
#    {'period': 'TTM', 'value': nan}]},
#  {'name': 'Purchases of intangibles',
#   'values': [{'period': '2017-12', 'value': nan},
#    {'period': '2018-12', 'value': nan},
#    {'period': '2019-12', 'value': nan},
#    {'period': '2020-12', 'value': nan},
#    {'period': '2021-12', 'value': nan},
#    {'period': 'TTM', 'value': nan}]},
#  {'name': 'Sales of intangibles',
#   'values': [{'period': '2017-12', 'value': nan},
#    {'period': '2018-12', 'value': nan},
#    {'period': '2019-12', 'value': nan},
#    {'period': '2020-12', 'value': nan},
#    {'period': '2021-12', 'value': nan},
#    {'period': 'TTM', 'value': nan}]},
#  {'name': 'Other investing activities',
#   'values': [{'period': '2017-12', 'value': nan},
#    {'period': '2018-12', 'value': nan},
#    {'period': '2019-12', 'value': nan},
#    {'period': '2020-12', 'value': nan},
#    {'period': '2021-12', 'value': nan},
#    {'period': 'TTM', 'value': nan}]},
#  {'name': 'Net cash used for investing activities',
#   'values': [{'period': '2017-12', 'value': -27819000000.0},
#    {'period': '2018-12', 'value': -12369000000.0},
#    {'period': '2019-12', 'value': -24281000000.0},
#    {'period': '2020-12', 'value': -59611000000.0},
#    {'period': '2021-12', 'value': -58154000000.0},
#    {'period': 'TTM', 'value': -58154000000.0}]},
#  {'name': 'Cash Flows From Financing Activities',
#   'values': [{'period': '2017-12', 'value': 9860000000.0},
#    {'period': '2018-12', 'value': -7686000000.0},
#    {'period': '2019-12', 'value': -10066000000.0},
#    {'period': '2020-12', 'value': -1104000000.0},
#    {'period': '2021-12', 'value': 6291000000.0},
#    {'period': 'TTM', 'value': 6291000000.0}]},
#  {'name': 'Debt issued',
#   'values': [{'period': '2017-12', 'value': 16231000000.0},
#    {'period': '2018-12', 'value': 768000000.0},
#    {'period': '2019-12', 'value': 2273000000.0},
#    {'period': '2020-12', 'value': 17321000000.0},
#    {'period': '2021-12', 'value': 26959000000.0},
#    {'period': 'TTM', 'value': 26959000000.0}]},
#  {'name': 'Debt repayment',
#   'values': [{'period': '2017-12', 'value': -6371000000.0},
#    {'period': '2018-12', 'value': -8454000000.0},
#    {'period': '2019-12', 'value': -12339000000.0},
#    {'period': '2020-12', 'value': -18425000000.0},
#    {'period': '2021-12', 'value': -20668000000.0},
#    {'period': 'TTM', 'value': -20668000000.0}]},
#  {'name': 'Preferred stock issued',
#   'values': [{'period': '2017-12', 'value': nan},
#    {'period': '2018-12', 'value': nan},
#    {'period': '2019-12', 'value': nan},
#    {'period': '2020-12', 'value': nan},
#    {'period': '2021-12', 'value': nan},
#    {'period': 'TTM', 'value': nan}]},
#  {'name': 'Preferred stock repaid',
#   'values': [{'period': '2017-12', 'value': nan},
#    {'period': '2018-12', 'value': nan},
#    {'period': '2019-12', 'value': nan},
#    {'period': '2020-12', 'value': nan},
#    {'period': '2021-12', 'value': nan},
#    {'period': 'TTM', 'value': nan}]},
#  {'name': 'Warrant issued',
#   'values': [{'period': '2017-12', 'value': nan},
#    {'period': '2018-12', 'value': nan},
#    {'period': '2019-12', 'value': nan},
#    {'period': '2020-12', 'value': nan},
#    {'period': '2021-12', 'value': nan},
#    {'period': 'TTM', 'value': nan}]},
#  {'name': 'Common stock issued',
#   'values': [{'period': '2017-12', 'value': nan},
#    {'period': '2018-12', 'value': nan},
#    {'period': '2019-12', 'value': nan},
#    {'period': '2020-12', 'value': nan},
#    {'period': '2021-12', 'value': nan},
#    {'period': 'TTM', 'value': nan}]},
#  {'name': 'Common stock repurchased',
#   'values': [{'period': '2017-12', 'value': nan},
#    {'period': '2018-12', 'value': nan},
#    {'period': '2019-12', 'value': nan},
#    {'period': '2020-12', 'value': nan},
#    {'period': '2021-12', 'value': nan},
#    {'period': 'TTM', 'value': nan}]},
#  {'name': 'Excess tax benefit from stock based compensation',
#   'values': [{'period': '2017-12', 'value': nan},
#    {'period': '2018-12', 'value': nan},
#    {'period': '2019-12', 'value': nan},
#    {'period': '2020-12', 'value': nan},
#    {'period': '2021-12', 'value': nan},
#    {'period': 'TTM', 'value': nan}]},
#  {'name': 'Dividend paid',
#   'values': [{'period': '2017-12', 'value': nan},
#    {'period': '2018-12', 'value': nan},
#    {'period': '2019-12', 'value': nan},
#    {'period': '2020-12', 'value': nan},
#    {'period': '2021-12', 'value': nan},
#    {'period': 'TTM', 'value': nan}]},
#  {'name': 'Dividend payable',
#   'values': [{'period': '2017-12', 'value': nan},
#    {'period': '2018-12', 'value': nan},
#    {'period': '2019-12', 'value': nan},
#    {'period': '2020-12', 'value': nan},
#    {'period': '2021-12', 'value': nan},
#    {'period': 'TTM', 'value': nan}]},
#  {'name': 'Other financing activities',
#   'values': [{'period': '2017-12', 'value': nan},
#    {'period': '2018-12', 'value': nan},
#    {'period': '2019-12', 'value': nan},
#    {'period': '2020-12', 'value': nan},
#    {'period': '2021-12', 'value': nan},
#    {'period': 'TTM', 'value': nan}]},
#  {'name': 'Net cash provided by (used for) financing activities',
#   'values': [{'period': '2017-12', 'value': 9860000000.0},
#    {'period': '2018-12', 'value': -7686000000.0},
#    {'period': '2019-12', 'value': -10066000000.0},
#    {'period': '2020-12', 'value': -1104000000.0},
#    {'period': '2021-12', 'value': 6291000000.0},
#    {'period': 'TTM', 'value': 6291000000.0}]},
#  {'name': 'Effect of exchange rate changes',
#   'values': [{'period': '2017-12', 'value': 713000000.0},
#    {'period': '2018-12', 'value': -351000000.0},
#    {'period': '2019-12', 'value': 70000000.0},
#    {'period': '2020-12', 'value': 618000000.0},
#    {'period': '2021-12', 'value': -364000000.0},
#    {'period': 'TTM', 'value': -364000000.0}]},
#  {'name': 'Net change in cash',
#   'values': [{'period': '2017-12', 'value': 1188000000.0},
#    {'period': '2018-12', 'value': 10317000000.0},
#    {'period': '2019-12', 'value': 4237000000.0},
#    {'period': '2020-12', 'value': 5967000000.0},
#    {'period': '2021-12', 'value': -5900000000.0},
#    {'period': 'TTM', 'value': -5900000000.0}]},
#  {'name': 'Cash at beginning of period',
#   'values': [{'period': '2017-12', 'value': 19334000000.0},
#    {'period': '2018-12', 'value': 21856000000.0},
#    {'period': '2019-12', 'value': 32173000000.0},
#    {'period': '2020-12', 'value': 36410000000.0},
#    {'period': '2021-12', 'value': 42377000000.0},
#    {'period': 'TTM', 'value': 42377000000.0}]},
#  {'name': 'Cash at end of period',
#   'values': [{'period': '2017-12', 'value': 20522000000.0},
#    {'period': '2018-12', 'value': 32173000000.0},
#    {'period': '2019-12', 'value': 36410000000.0},
#    {'period': '2020-12', 'value': 42377000000.0},
#    {'period': '2021-12', 'value': 36477000000.0},
#    {'period': 'TTM', 'value': 36477000000.0}]},
#  {'name': 'Free Cash Flow',
#   'values': [{'period': '2017-12', 'value': nan},
#    {'period': '2018-12', 'value': nan},
#    {'period': '2019-12', 'value': nan},
#    {'period': '2020-12', 'value': nan},
#    {'period': '2021-12', 'value': nan},
#    {'period': 'TTM', 'value': nan}]},
#  {'name': 'Operating cash flow',
#   'values': [{'period': '2017-12', 'value': 18434000000.0},
#    {'period': '2018-12', 'value': 30723000000.0},
#    {'period': '2019-12', 'value': 38514000000.0},
#    {'period': '2020-12', 'value': 66064000000.0},
#    {'period': '2021-12', 'value': 46327000000.0},
#    {'period': 'TTM', 'value': 46327000000.0}]},
#  {'name': 'Capital expenditure',
#   'values': [{'period': '2017-12', 'value': -11955000000.0},
#    {'period': '2018-12', 'value': -13427000000.0},
#    {'period': '2019-12', 'value': -16861000000.0},
#    {'period': '2020-12', 'value': -40140000000.0},
#    {'period': '2021-12', 'value': -61053000000.0},
#    {'period': 'TTM', 'value': -61053000000.0}]},
#  {'name': 'Free cash flow',
#   'values': [{'period': '2017-12', 'value': 6479000000.0},
#    {'period': '2018-12', 'value': 17296000000.0},
#    {'period': '2019-12', 'value': 21653000000.0},
#    {'period': '2020-12', 'value': 25924000000.0},
#    {'period': '2021-12', 'value': -14726000000.0},
#    {'period': 'TTM', 'value': -14726000000.0}]}]

# %%
from functools import partial

# %%
def get_results(stmt_type, ticker):
    print(stmt_type, ticker)

# %%
get_bs = partial(get_results, 'bs')

# %%
get_bs('AMZN')
# Out:
# bs AMZN
